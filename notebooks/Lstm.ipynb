# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve, auc
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Bidirectional
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt
import seaborn as sns
import time
from pathlib import Path
import shap
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf

# %%
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
def load_cicids2017_data(file_path):
    print("Loading and preparing data...")
    df = pd.read_csv(file_path)
    df = df.dropna()
    print(f"Dataset dimensions: {df.shape}")
    print(f"Class distribution:\n{df['Label'].value_counts()}")
    label_col = 'Label'
    if label_col not in df.columns:
        raise ValueError(f"Column '{label_col}' not found in CSV file")
    
    non_feature_cols = [label_col,'Destination Port']
    features = df.drop(columns=[col for col in non_feature_cols if col in df.columns],errors='ignore')
    labels = df[label_col]
    features = features.select_dtypes(include=[np.number])
    scaler = RobustScaler()
    features_scaled = scaler.fit_transform(features)
    label_encoder = LabelEncoder()
    labels_encoded = label_encoder.fit_transform(labels)
    labels_one_hot = to_categorical(labels_encoded)
    
    return features_scaled, labels_encoded, labels_one_hot, label_encoder.classes_, features.columns

# %%
def create_sequences(X, y, time_steps=5, stride=1):
    Xs, ys = [], []
    for i in range(0, len(X) - time_steps + 1, stride):
        Xs.append(X[i:(i + time_steps)])
        ys.append(y[i + time_steps - 1])
    return np.array(Xs), np.array(ys)

# %%
file_path = "C:/Users/ayana/Desktop/IDS project/Data/balanced_data.csv" 
X, y_encoded, y_one_hot, class_names, feature_names = load_cicids2017_data(file_path)
print(f"Detected classes: {class_names}")
print(f"Total samples: {len(X)}")
unique_classes, class_counts = np.unique(y_encoded, return_counts=True)
class_distribution = dict(zip(unique_classes, class_counts))
print("Class distribution:")
for class_idx, count in class_distribution.items():
    print(f"  Class {class_names[class_idx]}: {count} samples")

time_steps = 5  
stride = 2
X_seq, y_seq_one_hot = create_sequences(X, y_one_hot, time_steps, stride)
y_seq_encoded = np.argmax(y_seq_one_hot, axis=1)
unique_seq_classes, seq_class_counts = np.unique(y_seq_encoded, return_counts=True)
seq_class_distribution = dict(zip(unique_seq_classes, seq_class_counts))
print("\nClass distribution after sequencing:")
for class_idx, count in seq_class_distribution.items():
    print(f"  Class {class_names[class_idx]}: {count} samples")
# Out:
# Loading and preparing data...
# Dataset dimensions: (35000, 79)
# Class distribution:
# Label
# BENIGN          5000
# Attaques web    5000
# Bot             5000
# Infiltration    5000
# PortScan        5000
# DoS             5000
# Brute Force     5000
# Name: count, dtype: int64
# Detected classes: ['Attaques web' 'BENIGN' 'Bot' 'Brute Force' 'DoS' 'Infiltration'
#  'PortScan']
# Total samples: 35000
# Class distribution:
#   Class Attaques web: 5000 samples
#   Class BENIGN: 5000 samples
#   Class Bot: 5000 samples
#   Class Brute Force: 5000 samples
#   Class DoS: 5000 samples
#   Class Infiltration: 5000 samples
#   Class PortScan: 5000 samples
#
# Class distribution after sequencing:
#   Class Attaques web: 2467 samples
#   Class BENIGN: 2465 samples
#   Class Bot: 2560 samples
#   Class Brute Force: 2502 samples
#   Class DoS: 2524 samples
#   Class Infiltration: 2510 samples
#   Class PortScan: 2470 samples

# %%
print("\nSplitting data: 80% train, 10% validation, 10% test")
X_train, X_temp, y_train, y_temp, y_train_one_hot, y_temp_one_hot = train_test_split( X_seq, y_seq_encoded, y_seq_one_hot, test_size=0.2, random_state=RANDOM_SEED, stratify=y_seq_encoded)
X_val, X_test, y_val, y_test, y_val_one_hot, y_test_one_hot = train_test_split(X_temp, y_temp, y_temp_one_hot, test_size=0.5, random_state=RANDOM_SEED, stratify=y_temp)

print(f"Training set size: {X_train.shape[0]} samples")
print(f"Validation set size: {X_val.shape[0]} samples")
print(f"Test set size: {X_test.shape[0]} samples")
print(f"Input data shape: {X_train.shape}")
# Out:
# Splitting data: 80% train, 10% validation, 10% test
# Training set size: 13998 samples
# Validation set size: 1750 samples
# Test set size: 1750 samples
# Input data shape: (13998, 5, 77)

# %%
output_dir = Path('plots_lstm_improved')
output_dir.mkdir(exist_ok=True)
MODEL_DIR = Path('models')
MODEL_DIR.mkdir(exist_ok=True)

# %% [markdown]
# ##

# %%
input_shape = (time_steps, X.shape[1])  
num_classes = len(class_names)

model = build_model_with_attention(input_shape=input_shape, num_classes=num_classes)
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from pathlib import Path
MODEL_DIR = Path("models")  
MODEL_DIR.mkdir(parents=True, exist_ok=True)

callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5, verbose=1),
    ModelCheckpoint(filepath=MODEL_DIR / 'best_lstm_model.keras', save_best_only=True, verbose=1)
]
history = model.fit(
    X_train, y_train_one_hot,
    validation_data=(X_val, y_val_one_hot),
    epochs=250,
    batch_size=128,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.1779 - loss: 5.3427
# Epoch 1: val_loss improved from inf to 2.45880, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.1787 - loss: 5.3162 - val_accuracy: 0.4126 - val_loss: 2.4588 - learning_rate: 0.0030
# Epoch 2/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3829 - loss: 2.1753
# Epoch 2: val_loss improved from 2.45880 to 1.64598, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.3845 - loss: 2.1689 - val_accuracy: 0.6451 - val_loss: 1.6460 - learning_rate: 0.0030
# Epoch 3/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5764 - loss: 1.4533
# Epoch 3: val_loss improved from 1.64598 to 1.30583, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5767 - loss: 1.4526 - val_accuracy: 0.7246 - val_loss: 1.3058 - learning_rate: 0.0030
# Epoch 4/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6683 - loss: 1.1881
# Epoch 4: val_loss improved from 1.30583 to 1.00674, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6683 - loss: 1.1878 - val_accuracy: 0.7429 - val_loss: 1.0067 - learning_rate: 0.0030
# Epoch 5/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6854 - loss: 1.1213
# Epoch 5: val_loss improved from 1.00674 to 0.84103, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6854 - loss: 1.1209 - val_accuracy: 0.7526 - val_loss: 0.8410 - learning_rate: 0.0030
# Epoch 6/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6979 - loss: 1.0910
# Epoch 6: val_loss improved from 0.84103 to 0.81918, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.6979 - loss: 1.0908 - val_accuracy: 0.7697 - val_loss: 0.8192 - learning_rate: 0.0030
# Epoch 7/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6996 - loss: 1.0670
# Epoch 7: val_loss improved from 0.81918 to 0.81821, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.6996 - loss: 1.0670 - val_accuracy: 0.7686 - val_loss: 0.8182 - learning_rate: 0.0030
# Epoch 8/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7005 - loss: 1.0553
# Epoch 8: val_loss improved from 0.81821 to 0.78930, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.7005 - loss: 1.0553 - val_accuracy: 0.7720 - val_loss: 0.7893 - learning_rate: 0.0030
# Epoch 9/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7146 - loss: 1.0354
# Epoch 9: val_loss did not improve from 0.78930
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.7145 - loss: 1.0355 - val_accuracy: 0.7566 - val_loss: 0.8637 - learning_rate: 0.0030
# Epoch 10/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7053 - loss: 1.0707
# Epoch 10: val_loss did not improve from 0.78930
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7053 - loss: 1.0706 - val_accuracy: 0.7566 - val_loss: 0.8212 - learning_rate: 0.0030
# Epoch 11/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7035 - loss: 1.0405
# Epoch 11: val_loss improved from 0.78930 to 0.77670, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.7035 - loss: 1.0401 - val_accuracy: 0.7789 - val_loss: 0.7767 - learning_rate: 0.0030
# Epoch 12/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7169 - loss: 1.0083
# Epoch 12: val_loss did not improve from 0.77670
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7170 - loss: 1.0080 - val_accuracy: 0.7771 - val_loss: 0.7869 - learning_rate: 0.0030
# Epoch 13/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7160 - loss: 0.9828
# Epoch 13: val_loss did not improve from 0.77670
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.7160 - loss: 0.9829 - val_accuracy: 0.7754 - val_loss: 0.8108 - learning_rate: 0.0030
# Epoch 14/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7103 - loss: 1.0284
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.001500000013038516.
#
# Epoch 14: val_loss did not improve from 0.77670
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.7103 - loss: 1.0284 - val_accuracy: 0.7726 - val_loss: 0.8289 - learning_rate: 0.0030
# Epoch 15/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7235 - loss: 0.9778
# Epoch 15: val_loss improved from 0.77670 to 0.72181, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.7235 - loss: 0.9773 - val_accuracy: 0.7863 - val_loss: 0.7218 - learning_rate: 0.0015
# Epoch 16/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7363 - loss: 0.9053
# Epoch 16: val_loss improved from 0.72181 to 0.69880, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.7362 - loss: 0.9051 - val_accuracy: 0.7857 - val_loss: 0.6988 - learning_rate: 0.0015
# Epoch 17/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7355 - loss: 0.8715
# Epoch 17: val_loss improved from 0.69880 to 0.69145, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7354 - loss: 0.8715 - val_accuracy: 0.7834 - val_loss: 0.6915 - learning_rate: 0.0015
# Epoch 18/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7401 - loss: 0.8534
# Epoch 18: val_loss improved from 0.69145 to 0.66903, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.7400 - loss: 0.8533 - val_accuracy: 0.7897 - val_loss: 0.6690 - learning_rate: 0.0015
# Epoch 19/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7340 - loss: 0.8552
# Epoch 19: val_loss did not improve from 0.66903
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7340 - loss: 0.8553 - val_accuracy: 0.7937 - val_loss: 0.6758 - learning_rate: 0.0015
# Epoch 20/250
# 107/110 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7409 - loss: 0.8592
# Epoch 20: val_loss improved from 0.66903 to 0.65056, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.7408 - loss: 0.8590 - val_accuracy: 0.7971 - val_loss: 0.6506 - learning_rate: 0.0015
# Epoch 21/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7428 - loss: 0.8567
# Epoch 21: val_loss improved from 0.65056 to 0.64504, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.7427 - loss: 0.8566 - val_accuracy: 0.8006 - val_loss: 0.6450 - learning_rate: 0.0015
# Epoch 22/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7410 - loss: 0.8542
# Epoch 22: val_loss did not improve from 0.64504
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.7410 - loss: 0.8542 - val_accuracy: 0.7977 - val_loss: 0.6536 - learning_rate: 0.0015
# Epoch 23/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7423 - loss: 0.8203
# Epoch 23: val_loss improved from 0.64504 to 0.64104, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7422 - loss: 0.8205 - val_accuracy: 0.7943 - val_loss: 0.6410 - learning_rate: 0.0015
# Epoch 24/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7400 - loss: 0.8238
# Epoch 24: val_loss did not improve from 0.64104
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7399 - loss: 0.8239 - val_accuracy: 0.7920 - val_loss: 0.6425 - learning_rate: 0.0015
# Epoch 25/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7335 - loss: 0.8273
# Epoch 25: val_loss did not improve from 0.64104
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7335 - loss: 0.8273 - val_accuracy: 0.7891 - val_loss: 0.6515 - learning_rate: 0.0015
# Epoch 26/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7395 - loss: 0.8071
# Epoch 26: val_loss improved from 0.64104 to 0.62427, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.7396 - loss: 0.8070 - val_accuracy: 0.7903 - val_loss: 0.6243 - learning_rate: 0.0015
# Epoch 27/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7442 - loss: 0.8173
# Epoch 27: val_loss did not improve from 0.62427
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - accuracy: 0.7441 - loss: 0.8174 - val_accuracy: 0.7897 - val_loss: 0.6546 - learning_rate: 0.0015
# Epoch 28/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7355 - loss: 0.8522
# Epoch 28: val_loss did not improve from 0.62427
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7353 - loss: 0.8523 - val_accuracy: 0.7994 - val_loss: 0.6429 - learning_rate: 0.0015
# Epoch 29/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7324 - loss: 0.8272
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.000750000006519258.
#
# Epoch 29: val_loss did not improve from 0.62427
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7325 - loss: 0.8272 - val_accuracy: 0.7874 - val_loss: 0.6363 - learning_rate: 0.0015
# Epoch 30/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7472 - loss: 0.7947
# Epoch 30: val_loss improved from 0.62427 to 0.60060, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7472 - loss: 0.7946 - val_accuracy: 0.7983 - val_loss: 0.6006 - learning_rate: 7.5000e-04
# Epoch 31/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7443 - loss: 0.7626
# Epoch 31: val_loss improved from 0.60060 to 0.58928, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.7442 - loss: 0.7627 - val_accuracy: 0.7954 - val_loss: 0.5893 - learning_rate: 7.5000e-04
# Epoch 32/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7523 - loss: 0.7459
# Epoch 32: val_loss improved from 0.58928 to 0.57430, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7522 - loss: 0.7461 - val_accuracy: 0.8069 - val_loss: 0.5743 - learning_rate: 7.5000e-04
# Epoch 33/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7525 - loss: 0.7643
# Epoch 33: val_loss improved from 0.57430 to 0.56638, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7525 - loss: 0.7643 - val_accuracy: 0.8114 - val_loss: 0.5664 - learning_rate: 7.5000e-04
# Epoch 34/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7593 - loss: 0.7342
# Epoch 34: val_loss did not improve from 0.56638
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7592 - loss: 0.7344 - val_accuracy: 0.8034 - val_loss: 0.5716 - learning_rate: 7.5000e-04
# Epoch 35/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7429 - loss: 0.7532
# Epoch 35: val_loss did not improve from 0.56638
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.7429 - loss: 0.7532 - val_accuracy: 0.8229 - val_loss: 0.5787 - learning_rate: 7.5000e-04
# Epoch 36/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7500 - loss: 0.7478
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.000375000003259629.
#
# Epoch 36: val_loss did not improve from 0.56638
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7499 - loss: 0.7479 - val_accuracy: 0.8011 - val_loss: 0.5794 - learning_rate: 7.5000e-04
# Epoch 37/250
# 107/110 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7536 - loss: 0.7297
# Epoch 37: val_loss improved from 0.56638 to 0.55239, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.7536 - loss: 0.7296 - val_accuracy: 0.8091 - val_loss: 0.5524 - learning_rate: 3.7500e-04
# Epoch 38/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7582 - loss: 0.7133
# Epoch 38: val_loss improved from 0.55239 to 0.54418, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.7581 - loss: 0.7133 - val_accuracy: 0.8074 - val_loss: 0.5442 - learning_rate: 3.7500e-04
# Epoch 39/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7595 - loss: 0.6934
# Epoch 39: val_loss improved from 0.54418 to 0.54096, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7594 - loss: 0.6934 - val_accuracy: 0.8086 - val_loss: 0.5410 - learning_rate: 3.7500e-04
# Epoch 40/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7595 - loss: 0.6907
# Epoch 40: val_loss improved from 0.54096 to 0.53392, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.7594 - loss: 0.6907 - val_accuracy: 0.8149 - val_loss: 0.5339 - learning_rate: 3.7500e-04
# Epoch 41/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7585 - loss: 0.6946
# Epoch 41: val_loss improved from 0.53392 to 0.52143, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7585 - loss: 0.6946 - val_accuracy: 0.8131 - val_loss: 0.5214 - learning_rate: 3.7500e-04
# Epoch 42/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7646 - loss: 0.6861
# Epoch 42: val_loss did not improve from 0.52143
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7646 - loss: 0.6860 - val_accuracy: 0.8183 - val_loss: 0.5268 - learning_rate: 3.7500e-04
# Epoch 43/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7610 - loss: 0.6807
# Epoch 43: val_loss did not improve from 0.52143
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.7609 - loss: 0.6806 - val_accuracy: 0.8131 - val_loss: 0.5257 - learning_rate: 3.7500e-04
# Epoch 44/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7638 - loss: 0.6961
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0001875000016298145.
#
# Epoch 44: val_loss did not improve from 0.52143
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7637 - loss: 0.6959 - val_accuracy: 0.8080 - val_loss: 0.5306 - learning_rate: 3.7500e-04
# Epoch 45/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7599 - loss: 0.6801
# Epoch 45: val_loss improved from 0.52143 to 0.51582, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7599 - loss: 0.6799 - val_accuracy: 0.8109 - val_loss: 0.5158 - learning_rate: 1.8750e-04
# Epoch 46/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7628 - loss: 0.6714
# Epoch 46: val_loss improved from 0.51582 to 0.51385, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7628 - loss: 0.6713 - val_accuracy: 0.8120 - val_loss: 0.5138 - learning_rate: 1.8750e-04
# Epoch 47/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7644 - loss: 0.6610
# Epoch 47: val_loss improved from 0.51385 to 0.51247, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7645 - loss: 0.6609 - val_accuracy: 0.8086 - val_loss: 0.5125 - learning_rate: 1.8750e-04
# Epoch 48/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7662 - loss: 0.6569
# Epoch 48: val_loss improved from 0.51247 to 0.50883, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.7661 - loss: 0.6570 - val_accuracy: 0.8131 - val_loss: 0.5088 - learning_rate: 1.8750e-04
# Epoch 49/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7671 - loss: 0.6460
# Epoch 49: val_loss improved from 0.50883 to 0.50690, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.7671 - loss: 0.6461 - val_accuracy: 0.8103 - val_loss: 0.5069 - learning_rate: 1.8750e-04
# Epoch 50/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7670 - loss: 0.6604
# Epoch 50: val_loss improved from 0.50690 to 0.50489, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7669 - loss: 0.6603 - val_accuracy: 0.8109 - val_loss: 0.5049 - learning_rate: 1.8750e-04
# Epoch 51/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7691 - loss: 0.6399
# Epoch 51: val_loss improved from 0.50489 to 0.49984, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7690 - loss: 0.6400 - val_accuracy: 0.8120 - val_loss: 0.4998 - learning_rate: 1.8750e-04
# Epoch 52/250
# 107/110 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7687 - loss: 0.6385
# Epoch 52: val_loss did not improve from 0.49984
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.7686 - loss: 0.6387 - val_accuracy: 0.8229 - val_loss: 0.5040 - learning_rate: 1.8750e-04
# Epoch 53/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7676 - loss: 0.6442
# Epoch 53: val_loss improved from 0.49984 to 0.49882, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.7676 - loss: 0.6442 - val_accuracy: 0.8371 - val_loss: 0.4988 - learning_rate: 1.8750e-04
# Epoch 54/250
# 107/110 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7699 - loss: 0.6396
# Epoch 54: val_loss improved from 0.49882 to 0.49631, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7699 - loss: 0.6395 - val_accuracy: 0.8366 - val_loss: 0.4963 - learning_rate: 1.8750e-04
# Epoch 55/250
# 106/110 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7730 - loss: 0.6363
# Epoch 55: val_loss did not improve from 0.49631
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.7729 - loss: 0.6366 - val_accuracy: 0.8303 - val_loss: 0.4989 - learning_rate: 1.8750e-04
# Epoch 56/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7709 - loss: 0.6434
# Epoch 56: val_loss did not improve from 0.49631
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7708 - loss: 0.6434 - val_accuracy: 0.8349 - val_loss: 0.4993 - learning_rate: 1.8750e-04
# Epoch 57/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7689 - loss: 0.6395
# Epoch 57: val_loss improved from 0.49631 to 0.49530, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7688 - loss: 0.6395 - val_accuracy: 0.8360 - val_loss: 0.4953 - learning_rate: 1.8750e-04
# Epoch 58/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7698 - loss: 0.6340
# Epoch 58: val_loss did not improve from 0.49530
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7699 - loss: 0.6340 - val_accuracy: 0.8371 - val_loss: 0.4954 - learning_rate: 1.8750e-04
# Epoch 59/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7794 - loss: 0.6181
# Epoch 59: val_loss did not improve from 0.49530
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.7794 - loss: 0.6182 - val_accuracy: 0.8389 - val_loss: 0.4955 - learning_rate: 1.8750e-04
# Epoch 60/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7673 - loss: 0.6286
# Epoch 60: val_loss improved from 0.49530 to 0.49207, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7673 - loss: 0.6286 - val_accuracy: 0.8337 - val_loss: 0.4921 - learning_rate: 1.8750e-04
# Epoch 61/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7741 - loss: 0.6186
# Epoch 61: val_loss improved from 0.49207 to 0.49109, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.7741 - loss: 0.6186 - val_accuracy: 0.8371 - val_loss: 0.4911 - learning_rate: 1.8750e-04
# Epoch 62/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7800 - loss: 0.6187
# Epoch 62: val_loss did not improve from 0.49109
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7800 - loss: 0.6187 - val_accuracy: 0.8331 - val_loss: 0.4915 - learning_rate: 1.8750e-04
# Epoch 63/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7705 - loss: 0.6167
# Epoch 63: val_loss did not improve from 0.49109
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7704 - loss: 0.6168 - val_accuracy: 0.8343 - val_loss: 0.4926 - learning_rate: 1.8750e-04
# Epoch 64/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7778 - loss: 0.6195
# Epoch 64: val_loss improved from 0.49109 to 0.49026, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7778 - loss: 0.6196 - val_accuracy: 0.8354 - val_loss: 0.4903 - learning_rate: 1.8750e-04
# Epoch 65/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7785 - loss: 0.6231
# Epoch 65: val_loss did not improve from 0.49026
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.7784 - loss: 0.6233 - val_accuracy: 0.8349 - val_loss: 0.4961 - learning_rate: 1.8750e-04
# Epoch 66/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7710 - loss: 0.6167
# Epoch 66: val_loss improved from 0.49026 to 0.48604, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7711 - loss: 0.6167 - val_accuracy: 0.8297 - val_loss: 0.4860 - learning_rate: 1.8750e-04
# Epoch 67/250
# 106/110 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7761 - loss: 0.6245
# Epoch 67: val_loss did not improve from 0.48604
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.7760 - loss: 0.6246 - val_accuracy: 0.8343 - val_loss: 0.4900 - learning_rate: 1.8750e-04
# Epoch 68/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7682 - loss: 0.6123
# Epoch 68: val_loss improved from 0.48604 to 0.48486, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7683 - loss: 0.6124 - val_accuracy: 0.8366 - val_loss: 0.4849 - learning_rate: 1.8750e-04
# Epoch 69/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7784 - loss: 0.6146
# Epoch 69: val_loss improved from 0.48486 to 0.47869, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7784 - loss: 0.6146 - val_accuracy: 0.8400 - val_loss: 0.4787 - learning_rate: 1.8750e-04
# Epoch 70/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7756 - loss: 0.6067
# Epoch 70: val_loss improved from 0.47869 to 0.47652, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7755 - loss: 0.6069 - val_accuracy: 0.8366 - val_loss: 0.4765 - learning_rate: 1.8750e-04
# Epoch 71/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7747 - loss: 0.6113
# Epoch 71: val_loss did not improve from 0.47652
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.7747 - loss: 0.6113 - val_accuracy: 0.8331 - val_loss: 0.4785 - learning_rate: 1.8750e-04
# Epoch 72/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7752 - loss: 0.6132
# Epoch 72: val_loss did not improve from 0.47652
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7752 - loss: 0.6132 - val_accuracy: 0.8360 - val_loss: 0.4848 - learning_rate: 1.8750e-04
# Epoch 73/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7776 - loss: 0.6138
# Epoch 73: val_loss improved from 0.47652 to 0.47494, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.7776 - loss: 0.6138 - val_accuracy: 0.8360 - val_loss: 0.4749 - learning_rate: 1.8750e-04
# Epoch 74/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7687 - loss: 0.6172
# Epoch 74: val_loss improved from 0.47494 to 0.47449, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7688 - loss: 0.6173 - val_accuracy: 0.8377 - val_loss: 0.4745 - learning_rate: 1.8750e-04
# Epoch 75/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7733 - loss: 0.6180
# Epoch 75: val_loss did not improve from 0.47449
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7732 - loss: 0.6180 - val_accuracy: 0.8400 - val_loss: 0.4783 - learning_rate: 1.8750e-04
# Epoch 76/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7694 - loss: 0.6340
# Epoch 76: val_loss did not improve from 0.47449
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7694 - loss: 0.6339 - val_accuracy: 0.8354 - val_loss: 0.4808 - learning_rate: 1.8750e-04
# Epoch 77/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7815 - loss: 0.6171
# Epoch 77: ReduceLROnPlateau reducing learning rate to 9.375000081490725e-05.
#
# Epoch 77: val_loss did not improve from 0.47449
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.7814 - loss: 0.6173 - val_accuracy: 0.8394 - val_loss: 0.4774 - learning_rate: 1.8750e-04
# Epoch 78/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7774 - loss: 0.6069
# Epoch 78: val_loss did not improve from 0.47449
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.7774 - loss: 0.6070 - val_accuracy: 0.8383 - val_loss: 0.4763 - learning_rate: 9.3750e-05
# Epoch 79/250
# 107/110 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7786 - loss: 0.6105
# Epoch 79: val_loss improved from 0.47449 to 0.47321, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7786 - loss: 0.6107 - val_accuracy: 0.8389 - val_loss: 0.4732 - learning_rate: 9.3750e-05
# Epoch 80/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7810 - loss: 0.5963
# Epoch 80: val_loss improved from 0.47321 to 0.47117, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.7810 - loss: 0.5964 - val_accuracy: 0.8389 - val_loss: 0.4712 - learning_rate: 9.3750e-05
# Epoch 81/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7869 - loss: 0.5896
# Epoch 81: val_loss improved from 0.47117 to 0.47068, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.7867 - loss: 0.5898 - val_accuracy: 0.8371 - val_loss: 0.4707 - learning_rate: 9.3750e-05
# Epoch 82/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7849 - loss: 0.5970
# Epoch 82: val_loss improved from 0.47068 to 0.46900, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7848 - loss: 0.5972 - val_accuracy: 0.8411 - val_loss: 0.4690 - learning_rate: 9.3750e-05
# Epoch 83/250
# 107/110 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7833 - loss: 0.5876
# Epoch 83: val_loss improved from 0.46900 to 0.46745, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7832 - loss: 0.5878 - val_accuracy: 0.8394 - val_loss: 0.4674 - learning_rate: 9.3750e-05
# Epoch 84/250
# 107/110 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7876 - loss: 0.6040
# Epoch 84: val_loss did not improve from 0.46745
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.7874 - loss: 0.6039 - val_accuracy: 0.8389 - val_loss: 0.4720 - learning_rate: 9.3750e-05
# Epoch 85/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7806 - loss: 0.6117
# Epoch 85: val_loss did not improve from 0.46745
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7806 - loss: 0.6116 - val_accuracy: 0.8377 - val_loss: 0.4702 - learning_rate: 9.3750e-05
# Epoch 86/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7808 - loss: 0.5945
# Epoch 86: val_loss improved from 0.46745 to 0.46631, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7807 - loss: 0.5945 - val_accuracy: 0.8383 - val_loss: 0.4663 - learning_rate: 9.3750e-05
# Epoch 87/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7820 - loss: 0.5997
# Epoch 87: val_loss did not improve from 0.46631
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.7820 - loss: 0.5997 - val_accuracy: 0.8383 - val_loss: 0.4670 - learning_rate: 9.3750e-05
# Epoch 88/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7827 - loss: 0.5908
# Epoch 88: val_loss improved from 0.46631 to 0.46330, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7827 - loss: 0.5908 - val_accuracy: 0.8400 - val_loss: 0.4633 - learning_rate: 9.3750e-05
# Epoch 89/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7801 - loss: 0.5966
# Epoch 89: val_loss did not improve from 0.46330
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7800 - loss: 0.5966 - val_accuracy: 0.8389 - val_loss: 0.4670 - learning_rate: 9.3750e-05
# Epoch 90/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7825 - loss: 0.5922
# Epoch 90: val_loss did not improve from 0.46330
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.7824 - loss: 0.5922 - val_accuracy: 0.8394 - val_loss: 0.4669 - learning_rate: 9.3750e-05
# Epoch 91/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7858 - loss: 0.5844
# Epoch 91: val_loss improved from 0.46330 to 0.46261, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7857 - loss: 0.5846 - val_accuracy: 0.8394 - val_loss: 0.4626 - learning_rate: 9.3750e-05
# Epoch 92/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7756 - loss: 0.5978
# Epoch 92: val_loss improved from 0.46261 to 0.46191, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7757 - loss: 0.5979 - val_accuracy: 0.8383 - val_loss: 0.4619 - learning_rate: 9.3750e-05
# Epoch 93/250
# 107/110 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7861 - loss: 0.5858
# Epoch 93: val_loss did not improve from 0.46191
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7859 - loss: 0.5859 - val_accuracy: 0.8400 - val_loss: 0.4640 - learning_rate: 9.3750e-05
# Epoch 94/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7827 - loss: 0.5905
# Epoch 94: val_loss improved from 0.46191 to 0.45951, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7827 - loss: 0.5906 - val_accuracy: 0.8417 - val_loss: 0.4595 - learning_rate: 9.3750e-05
# Epoch 95/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7827 - loss: 0.5915
# Epoch 95: val_loss improved from 0.45951 to 0.45646, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.7827 - loss: 0.5914 - val_accuracy: 0.8411 - val_loss: 0.4565 - learning_rate: 9.3750e-05
# Epoch 96/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7850 - loss: 0.5803
# Epoch 96: val_loss did not improve from 0.45646
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7848 - loss: 0.5805 - val_accuracy: 0.8423 - val_loss: 0.4572 - learning_rate: 9.3750e-05
# Epoch 97/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7806 - loss: 0.5865
# Epoch 97: val_loss did not improve from 0.45646
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.7806 - loss: 0.5866 - val_accuracy: 0.8417 - val_loss: 0.4599 - learning_rate: 9.3750e-05
# Epoch 98/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7812 - loss: 0.5861
# Epoch 98: ReduceLROnPlateau reducing learning rate to 4.6875000407453626e-05.
#
# Epoch 98: val_loss did not improve from 0.45646
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7812 - loss: 0.5861 - val_accuracy: 0.8383 - val_loss: 0.4602 - learning_rate: 9.3750e-05
# Epoch 99/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7743 - loss: 0.5946
# Epoch 99: val_loss did not improve from 0.45646
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7743 - loss: 0.5946 - val_accuracy: 0.8389 - val_loss: 0.4603 - learning_rate: 4.6875e-05
# Epoch 100/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7867 - loss: 0.5871
# Epoch 100: val_loss did not improve from 0.45646
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.7867 - loss: 0.5871 - val_accuracy: 0.8377 - val_loss: 0.4626 - learning_rate: 4.6875e-05
# Epoch 101/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7833 - loss: 0.5843
# Epoch 101: ReduceLROnPlateau reducing learning rate to 2.3437500203726813e-05.
#
# Epoch 101: val_loss did not improve from 0.45646
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7833 - loss: 0.5843 - val_accuracy: 0.8417 - val_loss: 0.4583 - learning_rate: 4.6875e-05
# Epoch 102/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7837 - loss: 0.5766
# Epoch 102: val_loss did not improve from 0.45646
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7837 - loss: 0.5767 - val_accuracy: 0.8411 - val_loss: 0.4567 - learning_rate: 2.3438e-05
# Epoch 103/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7808 - loss: 0.5774
# Epoch 103: val_loss improved from 0.45646 to 0.45581, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7808 - loss: 0.5774 - val_accuracy: 0.8394 - val_loss: 0.4558 - learning_rate: 2.3438e-05
# Epoch 104/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7891 - loss: 0.5739
# Epoch 104: val_loss improved from 0.45581 to 0.45548, saving model to models\best_lstm_model.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7890 - loss: 0.5740 - val_accuracy: 0.8400 - val_loss: 0.4555 - learning_rate: 2.3438e-05
# Epoch 105/250
# 106/110 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7832 - loss: 0.5794
# Epoch 105: val_loss did not improve from 0.45548
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7831 - loss: 0.5794 - val_accuracy: 0.8411 - val_loss: 0.4557 - learning_rate: 2.3438e-05
# Epoch 106/250
# 107/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7824 - loss: 0.5774
# Epoch 106: val_loss did not improve from 0.45548
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7824 - loss: 0.5776 - val_accuracy: 0.8411 - val_loss: 0.4567 - learning_rate: 2.3438e-05
# Epoch 107/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7842 - loss: 0.5791
# Epoch 107: ReduceLROnPlateau reducing learning rate to 1.1718750101863407e-05.
#
# Epoch 107: val_loss did not improve from 0.45548
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7842 - loss: 0.5791 - val_accuracy: 0.8394 - val_loss: 0.4562 - learning_rate: 2.3438e-05
# Epoch 108/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7816 - loss: 0.5738
# Epoch 108: val_loss did not improve from 0.45548
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7815 - loss: 0.5738 - val_accuracy: 0.8406 - val_loss: 0.4568 - learning_rate: 1.1719e-05
# Epoch 109/250
# 108/110 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7920 - loss: 0.5625
# Epoch 109: val_loss did not improve from 0.45548
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7917 - loss: 0.5628 - val_accuracy: 0.8389 - val_loss: 0.4563 - learning_rate: 1.1719e-05
# Epoch 110/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7847 - loss: 0.5746
# Epoch 110: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 110: val_loss did not improve from 0.45548
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7847 - loss: 0.5746 - val_accuracy: 0.8394 - val_loss: 0.4568 - learning_rate: 1.1719e-05
# Epoch 111/250
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7862 - loss: 0.5686
# Epoch 111: val_loss did not improve from 0.45548
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7862 - loss: 0.5687 - val_accuracy: 0.8400 - val_loss: 0.4566 - learning_rate: 1.0000e-05
# Epoch 112/250
# 107/110 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7809 - loss: 0.5782
# Epoch 112: val_loss did not improve from 0.45548
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7810 - loss: 0.5782 - val_accuracy: 0.8406 - val_loss: 0.4566 - learning_rate: 1.0000e-05
# Epoch 113/250
# 107/110 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7880 - loss: 0.5705
# Epoch 113: val_loss did not improve from 0.45548
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7879 - loss: 0.5708 - val_accuracy: 0.8406 - val_loss: 0.4561 - learning_rate: 1.0000e-05
# Epoch 114/250
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7821 - loss: 0.5781
# Epoch 114: val_loss did not improve from 0.45548
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.7821 - loss: 0.5781 - val_accuracy: 0.8400 - val_loss: 0.4557 - learning_rate: 1.0000e-05
# Epoch 114: early stopping
# Restoring model weights from the end of the best epoch: 104.

# %%
ModelCheckpoint(filepath=MODEL_DIR/'best_lstm_model.keras',save_best_only=True, verbose=1)

# %%
loss, accuracy = best_model.evaluate(X_test, y_test_one_hot, verbose=1)
print(f"Test Loss: {loss:.4f} | Test Accuracy: {accuracy:.4f}")
# Out:
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8146 - loss: 0.4744
# Test Loss: 0.4690 | Test Accuracy: 0.8189
